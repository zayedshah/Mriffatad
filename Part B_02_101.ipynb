# %%
import pandas as pd

# %%
df = pd.read_table('Files/userid-timestamp-artid-artname-traid-traname.tsv',
                   names=['userid', 'timestamp', 'artid', 'artname', 'traid', 'traname'],
                   header=None)

# %%
g = df.groupby(['artname','traname']).size().sort_values(ascending=False).nlargest(100)

# %%
g[:10]
# Out:
# artname     traname
# Kanye West  See You In My Nightmares                           2069
#             Say You Will                                       2065
#             Heartless                                          2063
#             Love Lockdown                                      2062
#             Welcome To Heartbreak (Feat. Kid Cudi)             2059
#             Coldest Winter                                     2052
#             Paranoid (Feat. Mr. Hudson)                        2051
#             Amazing (Feat. Young Jeezy)                        2049
#             Pinocchio Story (Freestyle Live From Singapore)    2041
#             Bad News                                           2026
# dtype: int64

# %%
df[:10]
# Out:
#         userid             timestamp                                 artid  \
# 0  user_000001  2009-05-04T23:08:57Z  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1  user_000001  2009-05-04T13:54:10Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  user_000001  2009-05-04T13:52:04Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  user_000001  2009-05-04T13:42:52Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  user_000001  2009-05-04T13:42:11Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 5  user_000001  2009-05-04T13:38:31Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 6  user_000001  2009-05-04T13:33:28Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 7  user_000001  2009-05-04T13:23:45Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 8  user_000001  2009-05-04T13:19:22Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 9  user_000001  2009-05-04T13:13:38Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#      artname traid                                     traname
# 0  Deep Dish   NaN  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# ...

# %%
# pd.DataFrame(g.to_records())
type(g)
# Out:
# pandas.core.series.Series

# %%
g
# Out:
# artname                traname
# Kanye West             See You In My Nightmares                                                               2069
#                        Say You Will                                                                           2065
#                        Heartless                                                                              2063
#                        Love Lockdown                                                                          2062
#                        Welcome To Heartbreak (Feat. Kid Cudi)                                                 2059
#                        Coldest Winter                                                                         2052
#                        Paranoid (Feat. Mr. Hudson)                                                            2051
#                        Amazing (Feat. Young Jeezy)                                                            2049
# ...

# %%
g1 = df.groupby(['artname','traname']).size().sort_values(ascending=False).nlargest(100)

# %%
d1 = pd.DataFrame(g1.reset_index(name='Count'))

# %%
d1.columns = ['Artist','Title','NumberOfTimesPlayed']

# %%
d1
# Out:
#                    Artist                                              Title  \
# 0              Kanye West                           See You In My Nightmares
# 1              Kanye West                                       Say You Will
# 2              Kanye West                                          Heartless
# 3              Kanye West                                      Love Lockdown
# 4              Kanye West             Welcome To Heartbreak (Feat. Kid Cudi)
# 5              Kanye West                                     Coldest Winter
# 6              Kanye West                        Paranoid (Feat. Mr. Hudson)
# 7              Kanye West                        Amazing (Feat. Young Jeezy)
# 8              Kanye West    Pinocchio Story (Freestyle Live From Singapore)
# 9              Kanye West                                           Bad News
# 10             Kanye West                                            Robocop
# ...
